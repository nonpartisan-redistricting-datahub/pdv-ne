# %%
import pandas as pd
import geopandas as gp
import numpy as np 
import xlrd
import os
import fiona
from statistics import mean, median
import string
import math
import re

from shapely.geometry import Polygon
from shapely.ops import cascaded_union

# %% [markdown]
# # VEST NE 2018
#
# ## VEST Documentation
#
# ### Sources
#
# Election results from the Nebraska Secretary of State's office via email.
#
# ### Shapefiles
#
# Precinct shapefiles primarily from the U.S. Census Bureau's 2020 Redistricting Data Program Phase 2 release.
#
# Adams, Antelope, Box Butte, Buffalo, Burt, Butler, Chase, Cherry, Cuming, Custer, Dakota, Dawes, Dawson, Deuel, Dodge, Douglas, Garfield, Hamilton, Harlan, Holt, Kearney, Keith, Keya Paha, Kimball, Lincoln, Madison, Merrick, Morrill, Nemaha, Nuckolls, Otoe, Perkins, Phelps, Platte, Red Willow, Richardson, Saline, Sarpy, Scotts Bluff, Seward, Stanton, Thayer, Valley, and Washington either used a replacement shapefile or, more often, required tweaks based on PDF maps from county election officials and the geocoded voter registration file.
#
# Some counties reported one or more classes of votes at the county level. These were distributed by candidate based on the precinct-level reported vote.
#
# ### Races
#
# G18USSRFIS - Deb Fischer (Republican Party)<br>
# G18USSDRAY - Jane Raybould (Democratic Party)<br>
# G18USSLSCH - Jim Schultz (Libertarian Party)<br>
# <br>
# G18GOVRRIC - Pete Ricketts (Republican Party)<br>
# G18GOVDKRI - Bob Krist (Democratic Party)<br>
# <br>
# G18SOSREVN - Bob Evnen (Republican Party)<br>
# G18SOSDDAN - Spencer Danner (Democratic Party)<br>
# <br>
# G18TRERMUR - John Murante (Republican Party)<br>
# <br>
# G18ATGRPET - Doug Peterson (Republican Party)<br>
# <br>
# G18AUDRJAN - Charlie Janssen (Republican Party)<br>
# G18AUDDSKI - Jane Skinner (Democratic Party)<br>

# %% [markdown]
# ## Load in VEST file

# %%
vest_ne_2018 = gp.read_file("../vest/ne_2018/ne_2018.shp")

# %%
vest_ne_2018.plot()
# Out:
# <AxesSubplot:>

# %% [markdown]
# ## Build table of precinct-level election results from NE SOS Spreadsheets

# %% [markdown]
# These are going to be annoying to parse, so start some experiments.

# %%
adams_xls = pd.read_excel('../raw-from-source/2018-er/General-18-Precinct-Results/Adams.xls')

# %%
adams_xls
# Out:
#              Unnamed: 0 GENERAL Election - November 06, 2018  \
# 0                   NaN                         Adams County
# 1                   NaN                                  NaN
# 2                   NaN                                  NaN
# 3         Precinct Name                                  NaN
# 4                   NaN                                  NaN
# ...                 ...                                  ...
# 1327            Pauline                                  NaN
# 1328           Roseland                                  NaN
# 1329             Verona                                  NaN
# 1330  WestBlue/Highland                                  NaN
# 1331              Total                                  NaN
#
#                         Unnamed: 2 Unnamed: 3 Unnamed: 4 Unnamed: 5
# 0                              NaN        NaN        NaN        NaN
# 1                              NaN        NaN        NaN        NaN
# 2                              NaN        NaN        NaN        NaN
# 3     For United States Senator -         NaN        NaN        NaN
# 4                              NaN        NaN        NaN        NaN
# ...                            ...        ...        ...        ...
# 1327                            29         78        107        NaN
# 1328                            35        119        154        NaN
# 1329                            36         59         95        NaN
# 1330                            55        169        224        NaN
# 1331                          4570       5271       9841        NaN
#
# [1332 rows x 6 columns]

# %% [markdown]
# Notes for parsing Excel documents:
# - Ignore column B; it only contains the name of the county (which we have from the filename), and creates an unnecessary blank column in the vote tables.

# %%
# returns a cleaned NE 2018 county spreadsheet which contains the results of many races
def load_county_excel_sheet(path_to_file):
    county_xls = pd.read_excel(path_to_file, skiprows=1)
    # assign alphabetical column names to align with Excel's standard formatting
    cols = list(map(lambda e: chr(ord('@')+e, range(1, len(county_xls.columns)+1))))
    county_xls.columns = cols
    # drop column B from the table
    cols.remove('B')
    county_xls = county_xls[cols]
    # drop all the blank rows (all NaN)
    county_xls = county_xls.dropna(how='all')
    county_xls = county_xls.reset_index(drop=True)
    return county_xls
# Out:
#                                      A                             C  \
# 0                        Precinct Name  For United States Senator -
# 1                                  NaN            Deb Fischer  \nREP
# 2     (Countywide) Absentee/Early Vote                           878
# 3                                  1-A                           292
# 4                                  1-B                           195
# ...                                ...                           ...
# 1249                           Pauline                            29
# 1250                          Roseland                            35
# 1251                            Verona                            36
# 1252                 WestBlue/Highland                            55
# 1253                             Total                          4570
#
#                          D                   E      F
# 0                      NaN                 NaN    NaN
# 1     Jane Raybould  \nDEM  Jim Schultz  \nLIB  Total
# 2                      635                  43   1556
# 3                      141                  23    456
# 4                      122                  23    340
# ...                    ...                 ...    ...
# 1249                    78                 107    NaN
# 1250                   119                 154    NaN
# 1251                    59                  95    NaN
# 1252                   169                 224    NaN
# 1253                  5271                9841    NaN
#
# [1254 rows x 5 columns]

# %% [markdown]
# This gives us close to an ordered list of offices in this spreadsheet (ordered == from top to bottom).

# %%
adams_xls[(adams_xls['A'] == 'Precinct Name') & (~adams_xls['C'].isnull())]
# Out:
#                   A                                                  C    D  \
# 0     Precinct Name                       For United States Senator -   NaN
# 33    Precinct Name         For Representative in Congress - CG0003     NaN
# 66    Precinct Name                   For Governor and Lt. Governor -   NaN
# 99    Precinct Name                             For Secretary of State  NaN
# 132   Precinct Name                                For State Treasurer  NaN
# 165   Precinct Name                               For Attorney General  NaN
# 198   Precinct Name                     For Auditor of Public Accounts  NaN
# 231   Precinct Name  For Member of the State Board of Education - S...  NaN
# 264   Precinct Name  Shall Judge Julie A. Martin be retained in off...  NaN
# 297   Precinct Name  Shall Judge James Michael Fitzgerald be retain...  NaN
# 330   Precinct Name  Shall Judge Michael O. Mead be retained in off...  NaN
# 363   Precinct Name  Central Community College For Board of Governo...  NaN
# 396   Precinct Name  Little Blue Natural Resources District For Boa...  NaN
# 429   Precinct Name  Little Blue Natural Resources District For Boa...  NaN
# 462   Precinct Name  Little Blue Natural Resources District For Boa...  NaN
# 495   Precinct Name  Little Blue Natural Resources District For Boa...  NaN
# 528   Precinct Name  Little Blue Natural Resources District For Boa...  NaN
# 561   Precinct Name  Little Blue Natural Resources District For Boa...  NaN
# 594   Precinct Name  Little Blue Natural Resources District For Boa...  NaN
# 627   Precinct Name  Little Blue Natural Resources District For Boa...  NaN
# 660   Precinct Name  Little Blue Natural Resources District At Larg...  NaN
# 693   Precinct Name  Upper Big Blue Natural Resources District For ...  NaN
# 726   Precinct Name  Upper Big Blue Natural Resources District For ...  NaN
# 759   Precinct Name  Upper Big Blue Natural Resources District For ...  NaN
# 792   Precinct Name  Upper Big Blue Natural Resources District For ...  NaN
# 825   Precinct Name  Upper Big Blue Natural Resources District For ...  NaN
# 858   Precinct Name  Upper Big Blue Natural Resources District For ...  NaN
# 891   Precinct Name  Upper Big Blue Natural Resources District For ...  NaN
# 924   Precinct Name  Upper Big Blue Natural Resources District For ...  NaN
# 957   Precinct Name  Upper Big Blue Natural Resources District At L...  NaN
# 990   Precinct Name         Southern Public Power District - PP2903     NaN
# 1023  Precinct Name         Educational Service Unit No. 9 - ED0901     NaN
# 1056  Precinct Name         Educational Service Unit No. 9 - ED0903     NaN
# 1089  Precinct Name         Educational Service Unit No. 9 - ED0905     NaN
# 1122  Precinct Name         Educational Service Unit No. 9 - ED0907     NaN
# 1155  Precinct Name        Educational Service Unit No. 10 - ED1005     NaN
# 1188  Precinct Name        Educational Service Unit No. 11 - ED1105     NaN
# 1221  Precinct Name  <strong>PROPOSED BY INITIATIVE PETITION</stron...  NaN
#
#         E    F
# 0     NaN  NaN
# 33    NaN  NaN
# 66    NaN  NaN
# 99    NaN  NaN
# 132   NaN  NaN
# 165   NaN  NaN
# 198   NaN  NaN
# 231   NaN  NaN
# 264   NaN  NaN
# 297   NaN  NaN
# 330   NaN  NaN
# 363   NaN  NaN
# 396   NaN  NaN
# 429   NaN  NaN
# 462   NaN  NaN
# 495   NaN  NaN
# 528   NaN  NaN
# 561   NaN  NaN
# 594   NaN  NaN
# 627   NaN  NaN
# 660   NaN  NaN
# 693   NaN  NaN
# 726   NaN  NaN
# 759   NaN  NaN
# 792   NaN  NaN
# 825   NaN  NaN
# 858   NaN  NaN
# 891   NaN  NaN
# 924   NaN  NaN
# 957   NaN  NaN
# 990   NaN  NaN
# 1023  NaN  NaN
# 1056  NaN  NaN
# 1089  NaN  NaN
# 1122  NaN  NaN
# 1155  NaN  NaN
# 1188  NaN  NaN
# 1221  NaN  NaN

# %% [markdown]
# And these are the row numbers that correspond to the rows w/ office information, which we can use to extract just the office info w/ `.at`.

# %%
adams_xls[(adams_xls['A'] == 'Precinct Name') & (~adams_xls['C'].isnull())].index
# Out:
# Int64Index([   0,   33,   66,   99,  132,  165,  198,  231,  264,  297,  330,
#              363,  396,  429,  462,  495,  528,  561,  594,  627,  660,  693,
#              726,  759,  792,  825,  858,  891,  924,  957,  990, 1023, 1056,
#             1089, 1122, 1155, 1188, 1221],
#            dtype='int64')

# %% [markdown]
# But let's keep track of both "office" rows and "total" rows and see if their counts are identical. If they are, we know this data is in a predictable structure that we can extract from. (It may be good to check to ensure that adjacent row numbers are only one integer apart.)

# %%
office_indices = list(adams_xls[(adams_xls['A'] == 'Precinct Name') & (~adams_xls['C'].isnull())].index)
total_indices = list(adams_xls[adams_xls['A'] == 'Total'].index)
table_boundary_pairs = list(zip(office_indices, total_indices))
table_boundary_pairs

# check that there are an equal number of "office" rows and total rows. 
# If not, file is malformed and data must be extracted manually.
if len(office_indices) != len(total_indices):
    raise ValueException('Number of office rows {0} != number of total rows {1}.'.format(len(office_indices), len(total_indices)))

# check that there is no distance between each table. Since we've removed whitespace, distance likely means that
# our table separation routine failed and the races will have to be separated manually.  
for idx, pair in enumerate(table_boundary_pairs):
    if idx != len(table_boundary_pairs)-1:
        pair_next = table_boundary_pairs[idx+1]
        if pair_next[0] - pair[1] != 1:
            raise ValueException('Table boundary error detected. "Total" at row # {0}, Next "office" row at {1}'.format(pair[1], pair_next[0]))

# %%
table_boundary_pairs
# Out:
# [(0, 32),
#  (33, 65),
#  (66, 98),
#  (99, 131),
#  (132, 164),
#  (165, 197),
#  (198, 230),
#  (231, 263),
#  (264, 296),
#  (297, 329),
#  (330, 362),
#  (363, 395),
#  (396, 428),
#  (429, 461),
#  (462, 494),
#  (495, 527),
#  (528, 560),
#  (561, 593),
#  (594, 626),
#  (627, 659),
#  (660, 692),
#  (693, 725),
#  (726, 758),
#  (759, 791),
#  (792, 824),
#  (825, 857),
#  (858, 890),
#  (891, 923),
#  (924, 956),
#  (957, 989),
#  (990, 1022),
#  (1023, 1055),
#  (1056, 1088),
#  (1089, 1121),
#  (1122, 1154),
#  (1155, 1187),
#  (1188, 1220),
#  (1221, 1253)]

# %%
adams_xls.at[0, 'C']
# Out:
# 'For United States Senator - '

# %% [markdown]
# The row below the "office" row contain the candidates list for that office.

# %%
adams_xls.loc[0+1]
# Out:
# A                     NaN
# C      Deb Fischer  \nREP
# D    Jane Raybould  \nDEM
# E      Jim Schultz  \nLIB
# F                   Total
# Name: 1, dtype: object

# %%
# Cleans an excel row that contains candidate information for a sub-table in a 2018 county spreadsheet
# and returns a list of the candidates.
def extract_candidates_from_row(r):
    # eliminate NaN values and the total row. 
    l = list(filter(lambda e: not pd.isna(e), r))
    raw_candidates = list(filter(lambda e: e != 'Total', l))
    
    # partisan candidate names and their parties are delimited by newlines. 
    candidate_names = list(map(lambda e: e.split('\n')[0].strip(), raw_candidates))
    return candidate_names
    
l = list(adams_xls.loc[1])
extract_candidates_from_row(l)
# Out:
# ['Deb Fischer', 'Jane Raybould', 'Jim Schultz']

# %%
office_name_to_vest = {
    'For United States Senator -': 'Senate',
    'For Governor and Lt. Governor - ': 'Governor',
    'For Secretary of State': 'SOS',
    'For State Treasurer': 'Treasurer',
    'For Attorney General': 'AG',
    'For Auditor of Public Accounts': 'Auditor'
}

# %% [markdown]
# Given an Excel df, create a feeder method into an extraction routine

# %%
# county_xls should be cleaned and formatted 
def extract_races_from_excel(county_xls, county_name):
    # first, get the row indexes of the

# %% [markdown]
# Try to extract all offices from a county and see what happens

# %%
county_races = {}

office_indices = list(adams_xls[(adams_xls['A'] == 'Precinct Name') & (~adams_xls['C'].isnull())].index)
for o in office_indices:
    # row at df[o, 'C'] contains the name of the office. 
    office = adams_xls.at[o, 'C'].strip()
    if office in office_name_to_vest.values():
        office = office_name_to_vest[office]
    # next row contains the candidate list 
    candidates_list = extract_candidates_from_row(adams_xls[o+1])
    # the first row of race data starts on the next row, and it runs through df[(o_i+1)-2]
    adams_xls.loc[]

# %%
adams_xls.loc[3:5]
# Out:
#      A    C    D   E    F
# 3  1-A  292  141  23  456
# 4  1-B  195  122  23  340
# 5  1-C  179  121  12  312

# %% [markdown]
# ### Analyze the data for all counties

# %% [markdown]
# For now, we're going to <b>skip</b> the counties with 7 columns, because they're the minority and they could be done by hand if we really need to. The vast majority have six columns, so we're going to optimize this algorithm for data in that shape.

# %%
# build a list of excel files in the 2018-er directory
county_dfs = {}
input_files = os.listdir('../raw-from-source/2018-er/General-18-Precinct-Results/')
for fn in list(filter(lambda e: e.endswith('.xls'), input_files)):
    county_name = fn.split('.xls')[0]
    county_xls = pd.read_excel(os.path.join('../raw-from-source/2018-er/General-18-Precinct-Results/', fn), skiprows=1)
    if len(county_xls.columns) != 6:
        print('** Skipping {0} County ({1}) -- number of columns is not six! ({2})'.format(county_name, fn, len(county_xls.columns)))
        continue
    county_xls.columns = ['A', 'B', 'C', 'D', 'E', 'F']
    county_dfs[county_name] = county_xls.copy(deep=True)
# Out:
# ** Skipping Scotts Bluff County (Scotts Bluff.xls) -- number of columns is not six! (7)
# ** Skipping Sioux County (Sioux.xls) -- number of columns is not six! (7)
# ** Skipping Banner County (Banner.xls) -- number of columns is not six! (7)
# ** Skipping Morrill County (Morrill.xls) -- number of columns is not six! (7)

# %%
# combine them all together
counties_xls = pd.concat(county_dfs.values())
counties_xls.head(50)
# Out:
#                                    A   B  \
# 0                                NaN NaN
# 1                                NaN NaN
# 2                      Precinct Name NaN
# 3                                NaN NaN
# 4                                NaN NaN
# 5   (Countywide) Absentee/Early Vote NaN
# 6                     City of Hooper NaN
# 7                 City of North Bend NaN
# 8                   City of Scribner NaN
# 9                         Countywide NaN
# 10          Cuming/Everett Townships NaN
# 11                  Elkhorn Township NaN
# 12                        Fremont 1A NaN
# 13                        Fremont 1B NaN
# 14                        Fremont 1C NaN
# 15                        Fremont 1D NaN
# 16                        Fremont 1E NaN
# 17                        Fremont 2A NaN
# 18                        Fremont 2B NaN
# 19                        Fremont 2C NaN
# 20                        Fremont 2D NaN
# 21                        Fremont 2E NaN
# 22                        Fremont 3A NaN
# 23                        Fremont 3B NaN
# 24                        Fremont 3C NaN
# 25                        Fremont 3D NaN
# 26                        Fremont 3E NaN
# 27                        Fremont 4A NaN
# 28                        Fremont 4B NaN
# 29                        Fremont 4C NaN
# 30                        Fremont 4D NaN
# 31                        Fremont 4E NaN
# 32            Hooper/Logan Townships NaN
# 33         Nickerson/Maple Townships NaN
# 34                   Pebble Township NaN
# 35                       Platte East NaN
# 36                       Platte West NaN
# 37      Union/Cott/Ridg/PV Townships NaN
# 38                  Webster Township NaN
# 39                             Total NaN
# 40                               NaN NaN
# 41                     Precinct Name NaN
# 42                               NaN NaN
# 43                               NaN NaN
# 44  (Countywide) Absentee/Early Vote NaN
# 45                    City of Hooper NaN
# 46                City of North Bend NaN
# 47                  City of Scribner NaN
# 48                        Countywide NaN
# 49          Cuming/Everett Townships NaN
#
#                                              C                       D  \
# 0                                          NaN                     NaN
# 1                                          NaN                     NaN
# 2                 For United States Senator -                      NaN
# 3                                          NaN                     NaN
# 4                           Deb Fischer  \nREP    Jane Raybould  \nDEM
# 5                                          842                     569
# 6                                          198                      92
# 7                                          286                     120
# 8                                          246                      50
# 9                                            0                       0
# 10                                         157                      40
# 11                                          87                      28
# 12                                         290                     161
# 13                                         230                     146
# 14                                         438                     161
# 15                                         153                      86
# 16                                         307                     140
# 17                                         176                     121
# 18                                         162                     118
# 19                                         360                     169
# 20                                         136                      61
# 21                                         260                     132
# 22                                         128                      70
# 23                                          48                      62
# 24                                         110                      90
# 25                                         175                     123
# 26                                         147                     138
# 27                                         249                     132
# 28                                         149                     102
# 29                                         328                     191
# 30                                         432                     188
# 31                                         113                      76
# 32                                         238                      52
# 33                                         474                     140
# 34                                         148                      20
# 35                                         118                      62
# 36                                         326                     100
# 37                                          97                      25
# 38                                         219                      59
# 39                                        7827                    3824
# 40                                         NaN                     NaN
# 41  For Representative in Congress - CG0001                        NaN
# 42                                         NaN                     NaN
# 43                     Jeff Fortenberry  \nREP  Jessica McClure  \nDEM
# 44                                         894                     541
# 45                                         224                      80
# 46                                         314                     107
# 47                                         257                      48
# 48                                           0                       0
# 49                                         163                      36
#
#                      E      F
# 0                  NaN    NaN
# 1                  NaN    NaN
# 2                  NaN    NaN
# 3                  NaN    NaN
# 4   Jim Schultz  \nLIB  Total
# 5                   26   1437
# 6                   15    305
# 7                   15    421
# 8                   12    308
# 9                    0      0
# 10                   3    200
# 11                   1    116
# 12                  17    468
# 13                  18    394
# 14                  18    617
# 15                  10    249
# 16                  10    457
# 17                  17    314
# 18                  12    292
# 19                  21    550
# 20                  11    208
# 21                   8    400
# 22                   5    203
# 23                   3    113
# 24                  13    213
# 25                  20    318
# 26                  15    300
# 27                  16    397
# 28                  10    261
# 29                  21    540
# 30                  12    632
# 31                  12    201
# 32                   8    298
# 33                  15    629
# 34                   5    173
# 35                   9    189
# 36                  12    438
# 37                   3    125
# 38                  12    290
# 39                 405  12056
# 40                 NaN    NaN
# 41                 NaN    NaN
# 42                 NaN    NaN
# 43               Total    NaN
# 44                1435    NaN
# 45                 304    NaN
# 46                 421    NaN
# 47                 305    NaN
# 48                   0    NaN
# 49                 199    NaN

# %% [markdown]
# Look for surprises in the columns we're going to rely on to parse this mess

# %%
list(counties_xls['A'].unique())
# Out:
# [nan,
#  'Precinct Name',
#  '(Countywide) Absentee/Early Vote',
#  'City of Hooper',
#  'City of North Bend',
#  'City of Scribner',
#  'Countywide',
#  'Cuming/Everett Townships',
#  'Elkhorn Township',
#  'Fremont 1A',
#  'Fremont 1B',
#  'Fremont 1C',
#  'Fremont 1D',
#  'Fremont 1E',
#  'Fremont 2A',
#  'Fremont 2B',
#  'Fremont 2C',
#  'Fremont 2D',
#  'Fremont 2E',
#  'Fremont 3A',
#  'Fremont 3B',
#  'Fremont 3C',
#  'Fremont 3D',
#  'Fremont 3E',
#  'Fremont 4A',
#  'Fremont 4B',
#  'Fremont 4C',
#  'Fremont 4D',
#  'Fremont 4E',
#  'Hooper/Logan Townships',
#  'Nickerson/Maple Townships',
#  'Pebble Township',
#  'Platte East',
#  'Platte West',
#  'Union/Cott/Ridg/PV Townships',
#  'Webster Township',
#  'Total',
#  '(Countywide) Burt County PPD',
#  '(Countywide) Cuming PPD',
#  'Champion/Lamar',
#  'Imperial East',
#  'Imperial Rural',
#  'Imperial West',
#  'Wauneta',
#  'Curtis',
#  'Eustis',
#  'Garden Prairie',
#  'Maywood',
#  'Stockville',
#  'Coyote',
#  'Cozad East',
#  'Cozad West',
#  'Fairview',
#  'Farnam',
#  'German',
#  'Gillan',
#  'Gothenburg East',
#  'Gothenburg West',
#  'Grant',
#  'Kennebec',
#  'Lexington 1st',
#  'Lexington 2nd',
#  'Lexington 3rd',
#  'Lexington 4th',
#  'Lexington 5th',
#  'Overton',
#  'Platte',
#  'Ringgold',
#  'Woodriver',
#  'Eight',
#  'Eighteen',
#  'Eleven',
#  'Fifteen',
#  'Five',
#  'Four',
#  'Fourteen',
#  'Nine',
#  'Nineteen',
#  'One',
#  'Seven',
#  'Seventeen',
#  'Six',
#  'Sixteen',
#  'Ten',
#  'Thirteen',
#  'Three',
#  'Twelve',
#  'Twenty',
#  'Twenty-five',
#  'Twenty-four',
#  'Twenty-one',
#  'Twenty-six',
#  'Twenty-three',
#  'Twenty-two',
#  'Two',
#  'Brenna/Plum Creek/Hunter',
#  'Chapin/Hancock/Winside',
#  'Deer Creek/Sherman',
#  'First Ward',
#  'Fourth Ward',
#  'Hoskins/Garfield',
#  'Logan/Leslie',
#  'Second Ward',
#  'Strahan/Wilbur',
#  'Third Ward',
#  '(Countywide) Stanton County PPD',
#  '01 Antelope, Iowa & Verdigris',
#  '02 Atkinson & Surrounding Twps',
#  '03 Chambers & Surrounding Twps',
#  '04 Emmet & Northeast Twps',
#  '05 Ewing, Golden & Deloit',
#  '06 Inman Twp',
#  '07 Stuart & Cleveland Twps',
#  '08 Grattan & Shields Twps',
#  '09 Atkinson Ward I',
#  "10 O'Neill Ward I",
#  "11 O'Neill Ward II",
#  "12 O'Neill Ward III",
#  "13 O'Neill Ward IV",
#  'Center',
#  'Cosmo/Grant',
#  'Eaton',
#  'Liberty/Lincoln/May',
#  'Logan/Hayes/Sherman',
#  'Lowell',
#  'Mirage',
#  'Newark/Blaine',
#  'North',
#  'Oneida',
#  'South',
#  'Rock',
#  'Adams Area',
#  'Beatrice Ward 1',
#  'Beatrice Ward 2',
#  'Beatrice Ward 3',
#  'Beatrice Ward 4',
#  'Filley/Virginia Area',
#  'Homestead Area',
#  'NW Quad Area',
#  'Odell Area',
#  'Wymore Area',
#  'Berlin',
#  'Delaware',
#  'McWilliams',
#  'NC11',
#  'NC12',
#  'NC13',
#  'NC14',
#  'NC15',
#  'NC16',
#  'Palmyra',
#  'Russell',
#  'South Branch',
#  'Syracuse',
#  '1-A',
#  '1-B',
#  '1-C',
#  '2-A',
#  '2-B',
#  '2-C',
#  '2-D',
#  '2-E',
#  '3-A',
#  '3-B',
#  '3-C',
#  '3-D',
#  '3-E',
#  '4-A',
#  '4-B',
#  '4-C',
#  '4-D',
#  '4-E',
#  'Ayr',
#  'Blaine',
#  'Denver',
#  'Holstein',
#  'Juniata',
#  'Kenesaw',
#  'Pauline',
#  'Roseland',
#  'Verona',
#  'WestBlue/Highland',
#  'Gurley',
#  'Lodgepole',
#  'Potter',
#  'Sidney 1',
#  'Sidney 2',
#  'Sidney 3',
#  'Sidney 4',
#  'Sidney 5',
#  'Union Valley',
#  'District 1',
#  'District 2',
#  'District 3',
#  '01 - SSC Ward 1',
#  '02 - SSC Ward 2',
#  '03 - SSC Ward 3',
#  '04 - SSC Ward 4A',
#  '05 - SSC Ward 4AA',
#  '06 - SSC Ward 4B',
#  '07 - Covington Island',
#  '08 - Dakota City',
#  '09 - Dakota Rural',
#  '10 - Emerson',
#  '11 - Hubbard',
#  '12 - Omadi',
#  '13 - St. Johns',
#  'Precinct 1',
#  '1 A',
#  '1 A-1',
#  '1 B',
#  '1 D-1',
#  '1 D-10',
#  '1 D-2',
#  '1 D-4',
#  '1 D-5',
#  '1 D-6',
#  '1 D-7',
#  '1 D-8',
#  '1 D-9',
#  '1 E-2',
#  '1 E-3',
#  '1 E-4',
#  '1 E-5',
#  '1 E-6',
#  '1 E-7',
#  '1 E-8',
#  '1 E-9',
#  '1 F-1',
#  '1 F-2',
#  '1 F-3',
#  '10 A',
#  '10 B-1',
#  '10 B-2',
#  '10 B-4',
#  '10 B-5',
#  '10 C-12',
#  '10 C-4',
#  '10 C-5',
#  '10 C-6',
#  '10 C-7',
#  '10 C-8',
#  '10 D-1',
#  '10 D-2',
#  '10 D-3',
#  '10 D-4',
#  '10 D-8',
#  '10 E-1',
#  '10 E-10',
#  '10 E-11',
#  '10 E-12',
#  '10 E-14',
#  '10 E-15',
#  '10 E-16',
#  '10 E-17',
#  '10 E-4',
#  '10 E-5',
#  '10 E-7',
#  '10 E-8',
#  '10 F-1',
#  '10 F-10',
#  '10 F-11',
#  '10 F-12',
#  '10 F-14',
#  '10 F-15',
#  '10 F-16',
#  '10 F-2',
#  '10 F-3',
#  '10 F-4',
#  '10 F-5',
#  '10 F-6',
#  '10 F-7',
#  '10 G-1',
#  '10 G-2',
#  '10 G-3',
#  '10 G-4',
#  '10 G-5',
#  '10 G-6',
#  '10 G-7',
#  '10 H-1',
#  '10 H-2',
#  '10 H-3',
#  '10 H-4',
#  '10 H-5',
#  '10 H-6',
#  '10 H-7',
#  '10 H-8',
#  '11 A-1',
#  '11 A-2',
#  '11 B-1',
#  '11 D-2',
#  '11 E-1',
#  '11 E-10',
#  '11 E-3',
#  '11 E-5',
#  '11 E-6',
#  '11 E-7',
#  '12 A-10',
#  '12 A-4',
#  '12 A-5',
#  '12 A-7',
#  '12 A-8',
#  '12 A-9',
#  '12 B-1',
#  '12 B-2',
#  '12 B-4',
#  '12 B-6',
#  '12 B-7',
#  '12 B-8',
#  '12 C-2',
#  '12 C-6',
#  '12 C-7',
#  '12 D',
#  '12 F',
#  '12 G-1',
#  '12 G-2',
#  '2 A',
#  '2 C-1',
#  '2 C-2',
#  '2 C-3',
#  '2 D-1',
#  '2 D-2',
#  '2 D-3',
#  '2 D-5',
#  '3 A',
#  '3 D',
#  '4 A',
#  '5 B-1',
#  '5 C-1',
#  '5 C-3',
#  '5 E-3',
#  '5 E-4',
#  '5 E-5',
#  '5 E-6',
#  '5 E-7',
#  '5 E-8',
#  '5 E-9',
#  '6 A-1',
#  '6 D-2',
#  '6 E-1',
#  '6 E-2',
#  '6 F-1',
#  '7 A',
#  '7 D-2',
#  '8 A',
#  '8 C-2',
#  '9 A-1',
#  '9 B-1',
#  '9 C-1',
#  '9 D-1',
#  '9 E-1',
#  '9 E-2',
#  '9 E-4',
#  '9 E-5',
#  '9 F-1',
#  '9 F-10',
#  '9 F-11',
#  '9 F-2',
#  '9 F-3',
#  '9 F-4',
#  '9 F-5',
#  '9 F-9',
#  '9 G-1',
#  '9 G-2',
#  '9 G-3',
#  '9 G-4',
#  '9 G-5',
#  '9 G-6',
#  '9 G-7',
#  '9 G-8',
#  '9 G-9',
#  '9 H-1',
#  '9 H-2',
#  '9 H-3',
#  '9 H-4',
#  '9 H-5',
#  '9 H-6',
#  '9 H-7',
#  '9 H-8',
#  'Buda',
#  'Centerville',
#  'Denton',
#  'Elk',
#  'Garfield #1',
#  'Grant #1',
#  'Grant #2',
#  'Grant #3',
#  'Grant #4',
#  'Hickman',
#  'Middle Creek',
#  'Murdock South',
#  'Nemaha',
#  'North Bluff',
#  'Oak',
#  'Panama',
#  'Rock Creek',
#  'Saltillo #1',
#  'Saltillo #2',
#  'South Pass',
#  'Stevens Creek',
#  'Stockton',
#  'Waverly #2',
#  'Waverly North',
#  'Waverly South',
#  'West Salt',
#  'Yankee Hill East',
#  'Yankee Hill West',
#  'Precinct 10',
#  'Precinct 11',
#  'Precinct 2',
#  'Precinct 3',
#  'Precinct 4',
#  'Precinct 5',
#  'Precinct 6',
#  'Precinct 7',
#  'Precinct 8',
#  'Precinct 9',
#  'Beav,Genoa,Ccreek,Pcreek',
#  'Cedar,Tcreek,Sbranch',
#  'Ctnwd,Lferry,Full,Wnew,Enew',
#  'Fullerton',
#  'Genoa I',
#  'Genoa II',
#  'Bartley',
#  'Beaver',
#  'Indianola',
#  'Northwest',
#  'Southwest',
#  'Ward 1 Precinct 1',
#  'Ward 1 Precinct 2',
#  'Ward 1 Precinct 3',
#  'Ward 2 Precinct 1',
#  'Ward 2 Precinct 2',
#  'Ward 3 Precinct 1',
#  'Ward 3 Precinct 3',
#  'Ward 4 Precinct 1',
#  'Dannebrog',
#  'Elba',
#  'Loup Fork',
#  'Posen',
#  'Spring Creek',
#  'St. Libory',
#  'St. Paul Ward I',
#  'St. Paul Ward II',
#  'Sawyer',
#  'Ward 1',
#  'Ward 2',
#  'Ward 3',
#  'East Gordon',
#  'HaySprings',
#  'Mirage Flats',
#  'North Rushville',
#  'South Rushville',
#  'South Sheridan',
#  'West Gordon',
#  'Wounded Knee',
#  '(Countywide) Nebraska PPD',
#  '1st Ward - 1st Precinct',
#  '1st Ward - 2nd Precinct',
#  '2nd Ward - 1st Precinct',
#  '2nd Ward - 2nd Precinct',
#  '3rd Ward - 1st Precinct',
#  '3rd Ward - 2nd Precinct',
#  '4th Ward - 1st Precinct',
#  '4th Ward - 2nd Precinct',
#  'Avoca',
#  'Buccaneer Bay',
#  'East Louisville',
#  'Eight Mile Grove',
#  'Liberty',
#  'McKelverly',
#  'Mount Pleasant',
#  'Murdock',
#  'Nehawka',
#  'North Plattsmouth',
#  'North Rock Bluff',
#  'Salt Creek',
#  'South Bend',
#  'South Plattsmouth',
#  'South Rock Bluff',
#  'Stove Creek',
#  'Tipton',
#  'Weeping Water 1st Ward',
#  'Weeping Water 2nd Ward',
#  'West Louisville',
#  'West Rock Bluff',
#  'Brown-Henderson',
#  'Hays-McFadden',
#  'LeRoy-Baker',
#  'MABL',
#  'New York-Waco-Beaver-West Blue',
#  'Stewart-Thayer',
#  'Ward 2A',
#  'Ward 2B',
#  'Ward 4A',
#  'Ward 4B',
#  'Grant County',
#  'Clay Center City',
#  'Edgar Cons.',
#  'Fairfield 1st',
#  'Glenvil',
#  'Harvard Cons.',
#  'Inland Leicester',
#  'LLLM Cons.',
#  'Spring Ranch FF 2nd',
#  'Sutton 1st',
#  'Sutton 2nd',
#  'Sutton Twps',
#  'Nemaha I',
#  'Nemaha II',
#  'Sterling',
#  'Todd Creek',
#  'Western',
#  'Arapahoe',
#  'Beaver City',
#  'Cambridge',
#  'Edison',
#  'Hendley',
#  'Holbrook',
#  'Oxford',
#  'Wilsonville',
#  'Tryon 01',
#  'Arbor',
#  'Arlington',
#  'Central',
#  'Cuming City',
#  'Dana',
#  'Desoto',
#  'Fontanelle',
#  'Ft Calhoun East',
#  'Ft Calhoun West',
#  'Herman',
#  'Kennard',
#  'Lakeland',
#  'Northview',
#  'Skyline',
#  'Washington',
#  'Ashland Rural',
#  'Ashland Ward 1',
#  'Ashland Ward 2',
#  'Cedar Bluffs',
#  'Ceresco',
#  'District 4',
#  'Malmo',
#  'Marietta',
#  'Prague',
#  'Valparaiso',
#  'Wahoo Rural',
#  'Wahoo Ward I',
#  'Wahoo Ward II',
#  'Wahoo Ward III',
#  'Weston',
#  'Yutan',
#  'Franklin-Bone Creek',
#  'Linwood-Skull Creek-Platte',
#  'Oak Creek-Center',
#  'Plum Creek-Richardson',
#  'Read-Ulysses',
#  'Savannah-Alexis',
#  'Summit-Reading',
#  'Union-Olive',
#  'Ashton',
#  'Central LC',
#  'Harrison',
#  'North LC',
#  'Rockville',
#  'South LC',
#  'Central Alma',
#  'East Alma',
#  'Huntley-Ragan',
#  'Orleans',
#  'Republican City',
#  'Stamford',
#  'West Alma',
#  '01-02',
#  '01-03',
#  '01-04',
#  '01-05',
#  '01-07',
#  '01-08',
#  '01-09',
#  '01-10',
#  '01-11',
#  '01-12',
#  '01-13',
#  '01-14',
#  '01-15',
#  '01-16',
#  '01-17',
#  '01-18',
#  '01-19',
#  '01-20',
#  '01-21',
#  '01-22',
#  '01-23',
#  '01-24',
#  '01-25',
#  '01-26',
#  '01-27',
#  '01-28',
#  '01-29',
#  '01-30',
#  '01-31',
#  '02-01',
#  '02-02',
#  '02-03',
#  '02-04',
#  '02-05',
#  '02-06',
#  '02-07',
#  '02-08',
#  '02-09',
#  '02-10',
#  '02-11',
#  '02-12',
#  '02-13',
#  '02-14',
#  '02-15',
#  '02-16',
#  '02-17',
#  '02-18',
#  '02-19',
#  '02-20',
#  '02-21',
#  '02-22',
#  '02-23',
#  '02-24',
#  '02-25',
#  '03-02',
#  '03-03',
#  '03-04',
#  '03-05',
#  '03-06',
#  '03-07',
#  '03-08',
#  '03-09',
#  '03-10',
#  '03-11',
#  '03-12',
#  '03-13',
#  '03-14',
#  '03-15',
#  '03-16',
#  '03-17',
#  '03-18',
#  '03-19',
#  '03-20',
#  '03-21',
#  '03-22',
#  '03-23',
#  '03-24',
#  '03-25',
#  '03-26',
#  '04-01',
#  '04-02',
#  '04-03',
#  '04-04',
#  '04-05',
#  '04-06',
#  '04-07',
#  '04-08',
#  '04-09',
#  '04-10',
#  '04-11',
#  '04-12',
#  '04-13',
#  '04-14',
#  '04-15',
#  '04-16',
#  '04-17',
#  '04-18',
#  '04-19',
#  '04-20',
#  '04-21',
#  '05-01',
#  '05-02',
#  '05-03',
#  '05-05',
#  '05-06',
#  '05-07',
#  '05-09',
#  '05-10',
#  '05-11',
#  '05-12',
#  '05-13',
#  '05-14',
#  '05-15',
#  '05-16',
#  '05-17',
#  '05-18',
#  '05-19',
#  '05-23',
#  '05-24',
#  '05-25',
#  '05-26',
#  '05-27',
#  '05-28',
#  '05-30',
#  '05-31',
#  '05-32',
#  '05-33',
#  '05-34',
#  '05-35',
#  '06-02',
#  '06-03',
#  '06-04',
#  '06-07',
#  '06-08',
#  '06-09',
#  '06-10',
#  '06-11',
#  '06-12',
#  '06-13',
#  '06-14',
#  '06-15',
#  '06-16',
#  '06-17',
#  '06-18',
#  '06-19',
#  '06-20',
#  '06-21',
#  '06-22',
#  '06-23',
#  '06-24',
#  '06-25',
#  '06-26',
#  '06-27',
#  '06-28',
#  '06-29',
#  '06-30',
#  '06-31',
#  '06-32',
#  '06-33',
#  '06-34',
#  '06-35',
#  '07-01',
#  '07-02',
#  '07-03',
#  '07-04',
#  '07-05',
#  '07-09',
#  '07-10',
#  '07-11',
#  '07-12',
#  '07-13',
#  '07-14',
#  '07-15',
#  '07-16',
#  '07-17',
#  '07-18',
#  '07-19',
#  '07-20',
#  '07-21',
#  '07-24',
#  '07-25',
#  '07-26',
#  '07-27',
#  '07-28',
#  '07-29',
#  '07-30',
#  '07-31',
#  '07-32',
#  '07-33',
#  '07-34',
#  '08-01',
#  '08-02',
#  '08-03',
#  '08-04',
#  '08-05',
#  '08-06',
#  '08-07',
#  '08-08',
#  '08-09',
#  '08-10',
#  '08-11',
#  '08-12',
#  '08-13',
#  '08-14',
#  '08-15',
#  '08-16',
#  '08-17',
#  '08-18',
#  '08-19',
#  '08-20',
#  '08-23',
#  '08-24',
#  '08-27',
#  '08-36',
#  '08-37',
#  '08-39',
#  '08-40',
#  '08-41',
#  '08-42',
#  '08-43',
#  '08-44',
#  '08-45',
#  '08-46',
#  '08-47',
#  '08-48',
#  '08-49',
#  '08-50',
#  '08-51',
#  '08-52',
#  '08-53',
#  '08-54',
#  '08-55',
#  '08-56',
#  '08-57',
#  '08-58',
#  '08-59',
#  '08-60',
#  'Butte Basin McCulley',
#  'Lynch Bristow Mullen Bush',
#  'Spencer Morton',
#  'Chelsea/Stanton/Belle Prairie',
#  'Exeter Township',
#  'Fairmont Township',
#  'Liberty/Glengary/Franklin',
#  'Madison Township',
#  'Momence/Bryant/Hamilton',
#  'North Geneva',
#  'South Geneva & Geneva Township',
#  'West Blue/Grafton/Bennett',
#  'Buckley-Antelope-Endicott',
#  'Cub-Rock Creek',
#  'Eureka-Washington',
#  'Jefferson-Pleasant-Newton',
#  'Lincoln-Meridian-Fairbury-Rich',
#  'Plymouth-Gibson',
#  'Ward I',
#  'Ward II',
#  'Ward III',
#  'Ward IV',
#  'ARIZONA-RIVERSIDE',
#  'BELL-OAK-PERSH',
#  'CRAIG',
#  'DECATUR-QUINN',
#  'EVERETT-LOGAN',
#  'LYONS CITY',
#  'OAKLAND I',
#  'OAKLAND II',
#  'SILVERCREEK-SUMMIT',
#  'TEKAMAH I',
#  'TEKAMAH II',
#  'Bartlett',
#  'Ericson',
#  'Concord-Dixon-Clark',
#  'Daily-Hooker-Newcastle',
#  'Emerson',
#  'Galena-Silvercreek',
#  'Logan-Wakefield 3',
#  'Ottercreek',
#  'Ponca 1',
#  'Ponca 2',
#  'Ponca Township',
#  'Springbank',
#  'Wakefield 1',
#  'Wakefield 2',
#  'Clarkson 4',
#  'Howells 5',
#  'Schuyler 1',
#  'Schuyler 2',
#  'Schuyler 3',
#  'Brunswick Precinct',
#  'Clearwater Precinct',
#  'Elgin 1st Ward',
#  'Elgin 2nd Ward',
#  'Elgin Precinct',
#  'Neligh 1st Ward',
#  'Neligh 2nd Ward',
#  'Neligh Precinct',
#  'Oakdale Precinct',
#  'Orchard Precinct',
#  'Royal Precinct',
#  'Tilden 1st Ward',
#  'Tilden Precinct',
#  '1',
#  '2',
#  '3',
#  '4',
#  'Chapman',
#  'Clarksville East',
#  'Clarksville West',
#  'Lone Tree North',
#  'Lone Tree South',
#  'Loup',
#  'Mead',
#  'Midland',
#  'Prairie Creek',
#  'Prairie Island',
#  'Silver Creek',
#  'Vieregg',
#  'Butterfly',
#  'Dewey',
#  'Dimick',
#  'Elkhorn',
#  'Haymow',
#  'Kingsburg',
#  'Maple Creek',
#  'Pilger',
#  'Ramshorn',
#  'Spr Br2',
#  'Spring Branch',
#  'Stanton A',
#  'Stanton B',
#  'Stanton C',
#  'Union Creek',
#  'Thomas',
#  'C & B',
#  'Crete 1',
#  'Crete 2',
#  'Crete 3',
#  'DeWitt',
#  'Dorchester',
#  'Friend 1',
#  'Friend 2',
#  'Olive',
#  'South Fork',
#  'Wilber 1',
#  'Wilber 2',
#  'Big Springs',
#  'Chappell',
#  'Swan',
#  'Arago/Barada',
#  'East Muddy',
#  'FC Ward 1',
#  'FC Ward 2',
#  'FC Ward 3',
#  'FC Ward 4',
#  'FCRural/Ohio',
#  'Fran/Hrr/Spi',
#  'Grant Nemaha',
#  'Humboldt I',
#  'Humboldt II',
#  'Jefferson/Rulo',
#  'Salem',
#  'West Muddy/Porter',
#  'Rural Garfield County',
#  'Ward I City of Burwell',
#  'Ward II City of Burwell',
#  'Precicnt 10 (17-18)',
#  'Precicnt 13 (21)',
#  'Precicnt 3 (4)',
#  'Precicnt 4 (5-6-7)',
#  'Precicnt 7 (9A)',
#  'Precinct 1 (1)',
#  'Precinct 11 (19)',
#  'Precinct 12 (20)',
#  'Precinct 2 (2-3)',
#  'Precinct 5 (13-14)',
#  'Precinct 6 (8-9)',
#  'Precinct 8 (10-11-12)',
#  'Precinct 9 (15-16)',
#  'Boone',
#  'Cedar',
#  'Dublin-Bonanza',
#  'North Branch-Shell Creek',
#  'North Manchester',
#  'Oakland',
#  'Southeast Manchester',
#  'Southwest Manchester',
#  '(Countywide) Elkhorn Rural PPD',
#  'Alex/Gilead',
#  'Bruning/Belvidere',
#  'Chester/Byron/Hubbell',
#  'Davenport/Carleton',
#  'Deshler',
#  'Hebron North',
#  'Hebron South',
#  'Burchard',
#  'Pawnee 1',
#  'Pawnee 2',
#  'Steinauer',
#  'Table Rock',
#  'B',
#  'C',
#  'E',
#  'G',
#  'H',
#  'I',
#  'J',
#  'K',
#  'M-BX',
#  'M-CO',
#  'O-1',
#  'O-2',
#  'S-1',
#  'S-2',
#  'S-3',
#  'S-4',
#  'Campbell',
#  'East Franklin',
#  'Hildreth',
#  'West Franklin',
#  'Ainsworth Precinct',
#  'City of Ainsworth',
#  'The Pines',
#  'Greeley',
#  'Scotia',
#  'Spalding',
#  ...]

# %%
adams_xls
# Out:
#                       A   B                             C  \
# 0                   NaN NaN                           NaN
# 1                   NaN NaN                           NaN
# 2         Precinct Name NaN  For United States Senator -
# 3                   NaN NaN                           NaN
# 4                   NaN NaN            Deb Fischer  \nREP
# ...                 ...  ..                           ...
# 1326            Pauline NaN                            29
# 1327           Roseland NaN                            35
# 1328             Verona NaN                            36
# 1329  WestBlue/Highland NaN                            55
# 1330              Total NaN                          4570
#
#                          D                   E      F
# 0                      NaN                 NaN    NaN
# 1                      NaN                 NaN    NaN
# 2                      NaN                 NaN    NaN
# 3                      NaN                 NaN    NaN
# 4     Jane Raybould  \nDEM  Jim Schultz  \nLIB  Total
# ...                    ...                 ...    ...
# 1326                    78                 107    NaN
# 1327                   119                 154    NaN
# 1328                    59                  95    NaN
# 1329                   169                 224    NaN
# 1330                  5271                9841    NaN
#
# [1331 rows x 6 columns]
